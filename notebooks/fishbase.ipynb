# %%
# %load_ext rpy2.ipython

# %%
import pandas as pd 

species = pd.read_csv('fishbase/fishbase_species.csv', low_memory=False)
species.head()
# Out:
#    SpecCode        Genus  SpeciesRefNo  \
# 0     24523  Aborichthys       39226.0
# 1     65802  Aborichthys       95217.0
# 2     24524  Aborichthys        4832.0
# 3     67300  Aborichthys       95164.0
# 4     67609  Aborichthys       95217.0
#
#                                          Author FBname PicPreferredName  \
# 0                               Chaudhuri, 1913    NaN     Abkem_u1.jpg
# 1                                     Sen, 2009    NaN              NaN
# 2                                  Barman, 1985    NaN              NaN
# 3  Arunachalam, Raja, Malaiammal & Mayden, 2014    NaN              NaN
# 4                                 Kosygin, 2012    NaN              NaN
#
#   PicPreferredNameM PicPreferredNameF PicPreferredNameJ  FamCode  ... Profile  \
# 0               NaN               NaN               NaN      692  ...     NaN
# 1               NaN               NaN               NaN      692  ...     NaN
# ...

# %%
taxamatch = pd.read_csv('fishbase/fishbase_taxamatch.csv', low_memory=False)
taxamatch.head()
# Out:
#    SpecCode  SynCode       SynGenus       SynSpecies         Status  \
# 0         0   177190    Aborichthys       barapensis  accepted name
# 1         0   175718    Aborichthys         kailashi  accepted name
# 2         0   177270    Aborichthys       palinensis  accepted name
# 3         0   175689    Aborichthys        pangensis  accepted name
# 4         0   175203  Abyssobrotula  hadropercularis  accepted name
#
#        LastEpithet NormalizeGenus NormalizeSpecies NormalizeLastEpithet  \
# 0       barapensis      ABORICHTH         BARAPENS             BARAPENS
# 1         kailashi      ABORICHTH          KAILASH              KAILASH
# 2       palinensis      ABORICHTH         PALINENS             PALINENS
# 3        pangensis      ABORICHTH          PANGENS              PANGENS
# 4  hadropercularis   ABYSSOBROTUL    HADROPERCULAR        HADROPERCULAR
#
#   SoundexGenus SoundexSpecies SoundexLastEpithet
# 0         A162           B615               B615
# ...

# %%
# %%R
#
#
# library(rfishbase)
#
# enzymes <- fb_tbl("species")
# write.csv(enzymes, file = "fishbase/fishbase_species.csv", row.names = FALSE)

# %%
# %%R
#
#
# library(rfishbase)
#
#
# write.csv(diet("Mola mola"), file = "example_diet.csv", row.names = FALSE)
# Out:
# Joining with `by = join_by(SpecCode)`

# %%
# %%R
#
# library(rfishbase)
#
# write.csv(species("Mola mola"), file = "example_species.csv", row.names = FALSE)
# Out:
# Joining with `by = join_by(SpecCode)`
